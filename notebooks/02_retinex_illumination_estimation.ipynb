# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"We are using : {device} device")
# Out:
# We are using : cuda device

# %%
BASE_PATH = "../data/LOL"

TRAIN_LOW = os.path.join(BASE_PATH, "our485", "low")
TRAIN_HIGH = os.path.join(BASE_PATH, "our485", "high")

# %%
class IlluminationDataset(Dataset):
    def __init__(self, low_dir, high_dir):
        self.low_images = sorted(os.listdir(low_dir))
        self.high_images = sorted(os.listdir(high_dir))
        self.low_dir = low_dir
        self.high_dir = high_dir

    def __len__(self):
        return len(self.low_images)

    def __getitem__(self, idx):
        low_path = os.path.join(self.low_dir, self.low_images[idx])
        high_path = os.path.join(self.high_dir, self.high_images[idx])

        low_img = cv2.imread(low_path)
        high_img = cv2.imread(high_path)

        low_img = cv2.cvtColor(low_img, cv2.COLOR_BGR2RGB)
        high_img = cv2.cvtColor(high_img, cv2.COLOR_BGR2RGB)

        low_img = low_img.astype(np.float32) / 255.0
        high_img = high_img.astype(np.float32) / 255.0

        low_img = torch.from_numpy(low_img).permute(2, 0, 1)
        high_img = torch.from_numpy(high_img).permute(2, 0, 1)

        return low_img, high_img

# %%
from torch.utils.data import random_split

dataset = IlluminationDataset(TRAIN_LOW, TRAIN_HIGH)

train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)

print("Train samples:", train_size)
print("Validation samples:", val_size)
# Out:
# Train samples: 436
# Validation samples: 49

# %%
class IlluminationNet(nn.Module):
    def __init__(self):
        super(IlluminationNet, self).__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 32, 3, padding=1),
            nn.ReLU()
        )

        self.decoder = nn.Sequential(
            nn.Conv2d(32, 1, 3, padding=1),
            nn.Sigmoid()   # Illumination map in [0,1]
        )

    def forward(self, x):
        x = self.encoder(x)
        illumination = self.decoder(x)
        return illumination

# %%
def correct_illumination(low_img, illumination, eps=1e-4):
    return low_img / (illumination + eps)

# %%
def smoothness_loss(illumination):
    dx = torch.abs(illumination[:, :, :, :-1] - illumination[:, :, :, 1:])
    dy = torch.abs(illumination[:, :, :-1, :] - illumination[:, :, 1:, :])
    return torch.mean(dx) + torch.mean(dy)

# %%
model = IlluminationNet().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
l1_loss = nn.L1Loss()
import time
import math
def psnr(pred, target):
    mse = torch.mean((pred - target) ** 2)
    if mse == 0:
        return 100
    return 20 * torch.log10(1.0 / torch.sqrt(mse))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 model = IlluminationNet().to(device)
# ----> 2 optimizer = optim.Adam(model.parameters(), lr=1e-4)
#       3 l1_loss = nn.L1Loss()
#       4 import time
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\adam.py:100, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused, decoupled_weight_decay)
#      85         raise ValueError("Tensor betas[1] must be 1-element")
#      87 defaults = dict(
#      88     lr=lr,
#      89     betas=betas,
#    (...)     98     decoupled_weight_decay=decoupled_weight_decay,
#      99 )
# --> 100 super().__init__(params, defaults)
#     102 if fused:
#     103     if differentiable:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\optim\optimizer.py:369, in Optimizer.__init__(self, params, defaults)
#     366     param_groups = [{"params": param_groups}]
#     368 for param_group in param_groups:
# --> 369     self.add_param_group(cast(dict, param_group))
#     371 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     372 # which I don't think exists
#     373 # https://github.com/pytorch/pytorch/issues/72948
#     374 self._warned_capturable_if_run_uncaptured = True
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_compile.py:46, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      44 disable_fn = getattr(fn, "__dynamo_disable", None)
#      45 if disable_fn is None:
# ---> 46     import torch._dynamo
#      48     disable_fn = torch._dynamo.disable(fn, recursive)
#      49     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)      8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\convert_frame.py:52
#      50 from torch._C._dynamo.guards import GlobalStateGuard
#      51 from torch._dynamo.distributed import get_compile_pg
# ---> 52 from torch._dynamo.symbolic_convert import TensorifyState
#      53 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      54 from torch._logging import structured
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\symbolic_convert.py:57
#      54 from torch.fx.experimental.symbolic_shapes import guard_bool
#      55 from torch.utils._functools import cache_method
# ---> 57 from . import (
#      58     config,
#      59     exc,
#      60     graph_break_hints,
#      61     logging as torchdynamo_logging,
#      62     trace_rules,
#      63     variables,
#      64 )
#      65 from .bytecode_analysis import (
#      66     get_indexof,
#      67     JUMP_OPNAMES,
#      68     livevars_analysis,
#      69     propagate_line_nums,
#      70 )
#      71 from .bytecode_transformation import (
#      72     cleaned_instructions,
#      73     create_call_function,
#    (...)     80     unique_id,
#      81 )
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\trace_rules.py:32
#      30 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      31 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 32 from .variables import (
#      33     BuiltinVariable,
#      34     FunctionalCallVariable,
#      35     FunctorchHigherOrderVariable,
#      36     LocalGeneratorFunctionVariable,
#      37     LocalGeneratorObjectVariable,
#      38     NestedUserFunctionVariable,
#      39     PolyfilledFunctionVariable,
#      40     SkipFunctionVariable,
#      41     TorchInGraphFunctionVariable,
#      42     UserFunctionVariable,
#      43     UserMethodVariable,
#      44 )
#      47 np: Optional[types.ModuleType] = None
#      48 try:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\variables\__init__.py:19
#       1 """
#       2 This package implements variable tracking and symbolic execution capabilities for Dynamo,
#       3 which are essential for converting Python code into FX graphs. It provides a comprehensive
#    (...)     16 allows Dynamo to accurately trace and optimize Python code while preserving its semantics.
#      17 """
# ---> 19 from .base import VariableTracker
#      20 from .builtin import BuiltinVariable
#      21 from .constant import ConstantVariable, EnumVariable
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\variables\base.py:581
#     577     else:
#     578         return " ".join(map(typestr, objs))
# --> 581 from . import builder
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\variables\builder.py:241
#     232 from .sdpa import SDPAParamsVariable
#     233 from .tensor import (
#     234     NumpyNdarrayVariable,
#     235     supported_const_comparison_op_values,
#    (...)    239     UnspecializedPythonVariable,
#     240 )
# --> 241 from .torch import (
#     242     DispatchKeySetVariable,
#     243     FuncTorchInterpreterVariable,
#     244     TorchCtxManagerClassVariable,
#     245     TorchInGraphFunctionVariable,
#     246 )
#     247 from .torch_function import (
#     248     build_torch_function_fn,
#     249     TensorWithTFOverrideVariable,
#     250     torch_function_mode_stack_state_mgr,
#     251     TorchFunctionModeVariable,
#     252 )
#     253 from .user_defined import (
#     254     FrozenDataClassVariable,
#     255     KeyedJaggedTensorVariable,
#    (...)    263     UserDefinedTupleVariable,
#     264 )
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\variables\torch.py:176
#     166 constant_fold_functions_need_guards = dict.fromkeys(constant_fold_functions_need_guards)
#     167 constant_fold_functions = dict.fromkeys(constant_fold_functions)
#     170 tracing_state_functions = {
#     171     torch.jit.is_scripting: False,
#     172     torch.jit.is_tracing: False,
#     173     torch._C._get_tracing_state: None,
#     174     torch.fx._symbolic_trace.is_fx_tracing: False,
#     175     torch.onnx.is_in_onnx_export: False,
# --> 176     torch._dynamo.external_utils.is_compiling: True,
#     177     torch._utils.is_compiling: True,
#     178     torch.compiler.is_compiling: True,
#     179     torch.compiler.is_dynamo_compiling: True,
#     180     torch.compiler.is_exporting: True,
#     181     torch.nn.modules.activation._is_make_fx_tracing: False,
#     182 }
#     184 bin_ops = dict.fromkeys(["add", "sub", "mul", "div", "sqrt"])
#     186 dispatch_key_set_functions = {
#     187     torch._C._dispatch_keys,
#     188     torch._C._dispatch_tls_local_include_set,
#     189     torch._C._dispatch_tls_local_exclude_set,
#     190 }
#
# AttributeError: partially initialized module 'torch._dynamo' has no attribute 'external_utils' (most likely due to a circular import)

# %%
train_losses = []
val_losses = []
val_psnrs = []
epoch_times = []



num_epochs = 100
best_val_loss = float("inf")

for epoch in range(num_epochs):
    start_time = time.time()

    # -------- TRAINING --------
    model.train()
    train_loss = 0.0

    for low_img, high_img in train_loader:
        low_img = low_img.to(device)
        high_img = high_img.to(device)

        illumination = model(low_img)
        corrected = correct_illumination(low_img, illumination)

        loss_recon = l1_loss(corrected, high_img)
        loss_smooth = smoothness_loss(illumination)

        loss = loss_recon + 0.1 * loss_smooth

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_loader)

    # -------- VALIDATION --------
    model.eval()
    val_loss = 0.0
    val_psnr = 0.0

    with torch.no_grad():
        for low_img, high_img in val_loader:
            low_img = low_img.to(device)
            high_img = high_img.to(device)

            illumination = model(low_img)
            corrected = correct_illumination(low_img, illumination)

            loss_recon = l1_loss(corrected, high_img)
            loss_smooth = smoothness_loss(illumination)

            loss = loss_recon + 0.1 * loss_smooth

            val_loss += loss.item()
            val_psnr += psnr(corrected, high_img).item()

    val_loss /= len(val_loader)
    val_psnr /= len(val_loader)
    
    epoch_time = time.time() - start_time



    train_losses.append(train_loss)
    val_losses.append(val_loss)
    val_psnrs.append(val_psnr)
    epoch_times.append(epoch_time)


    # -------- SAVE BEST MODEL --------
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "../results/illumination_net_best.pth")

    print(
        f"Epoch [{epoch+1:03d}/{num_epochs}] | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Val PSNR: {val_psnr:.2f} dB | "
        f"Time: {epoch_time:.2f}s"
    )

# %%
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(14,10))

# ---- Train vs Validation Loss ----
plt.subplot(2,2,1)
plt.plot(epochs, train_losses, label="Train Loss")
plt.plot(epochs, val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)

# ---- Validation PSNR ----
plt.subplot(2,2,2)
plt.plot(epochs, val_psnrs, color="green")
plt.xlabel("Epoch")
plt.ylabel("PSNR (dB)")
plt.title("Validation PSNR")
plt.grid(True)

# ---- Epoch Time ----
plt.subplot(2,2,3)
plt.plot(epochs, epoch_times, color="orange")
plt.xlabel("Epoch")
plt.ylabel("Time (seconds)")
plt.title("Epoch Time")
plt.grid(True)

plt.tight_layout()
plt.show()
