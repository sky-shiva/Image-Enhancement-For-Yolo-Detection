# %% [markdown]
# # YOLO Detection on Enhanced Images
#
# ## Objective
# This notebook evaluates YOLO object detection performance on enhanced images
# generated by the Retinex-based enhancement pipeline and compares the results
# with baseline detection on raw low-light images.

# %%
from ultralytics import YOLO
import os
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")

# %%
# Enhanced images from Notebook 04
ENHANCED_IMG_DIR = "../results/enhanced_images"

# YOLO output (enhanced)
ENHANCED_OUT_PROJECT = "results/detection_outputs/enhanced"
ENHANCED_RUN_NAME = "enhanced_images"

# %%
from ultralytics import YOLO
import os

model = YOLO("yolov8n.pt")

ENHANCED_IMG_DIR = "../results/enhanced_images"

PROJECT_PATH = "results/detection_outputs/enhanced"
RUN_NAME = "enhanced_images"

image_files = sorted(os.listdir(ENHANCED_IMG_DIR))

for img_name in image_files:
    img_path = os.path.join(ENHANCED_IMG_DIR, img_name)

    model(
        img_path,
        conf=0.10,
        iou=0.45,
        save=True,
        project=PROJECT_PATH,
        name=RUN_NAME,
        exist_ok=True
    )

print("YOLO inference on enhanced images completed.")
# Out:
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\1.png: 640x640 1 refrigerator, 7.6ms
# Speed: 3.9ms preprocess, 7.6ms inference, 17.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\111.png: 640x640 1 bottle, 1 cup, 1 orange, 1 vase, 11.0ms
# Speed: 7.1ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\146.png: 640x640 1 surfboard, 1 clock, 21.3ms
# Speed: 4.8ms preprocess, 21.3ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\179.png: 640x640 1 tie, 2 toothbrushs, 16.6ms
# Speed: 9.9ms preprocess, 16.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\23.png: 640x640 2 persons, 15.0ms
# Speed: 8.7ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\493.png: 640x640 2 persons, 1 bottle, 1 cake, 1 teddy bear, 14.1ms
# Speed: 7.0ms preprocess, 14.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\547.png: 640x640 1 person, 1 book, 9.0ms
# Speed: 9.6ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\55.png: 640x640 1 oven, 14.7ms
# Speed: 3.7ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\665.png: 640x640 2 sinks, 11.6ms
# Speed: 6.9ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\669.png: 640x640 2 persons, 1 bottle, 1 tv, 13.0ms
# Speed: 6.3ms preprocess, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\748.png: 640x640 6 chairs, 1 potted plant, 1 vase, 35.8ms
# Speed: 11.5ms preprocess, 35.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\778.png: 640x640 (no detections), 11.4ms
# Speed: 4.4ms preprocess, 11.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\780.png: 640x640 (no detections), 13.7ms
# Speed: 7.4ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
#
# image 1/1 c:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\..\results\enhanced_images\79.png: 640x640 2 sinks, 12.5ms
# Speed: 6.7ms preprocess, 12.5ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\IMAGE_ENHANCEMENT_YOLO_DETECTION\totalloltraining\runs\detect\results\detection_outputs\enhanced\enhanced_images
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 16
#      13 for img_name in image_files:
#      14     img_path = os.path.join(ENHANCED_IMG_DIR, img_name)
# ---> 16     model(
#      17         img_path,
#      18         conf=0.10,
#      19         iou=0.45,
#      20         save=True,
#      21         project=PROJECT_PATH,
#      22         name=RUN_NAME,
#      23         exist_ok=True
#      24     )
#      26 print("YOLO inference on enhanced images completed.")
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:299, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     295     self.setup_model(model)
#     297 with self._lock:  # for thread-safe inference
#     298     # Setup source every time predict is called
# --> 299     self.setup_source(source if source is not None else self.args.source)
#     301     # Check if save_dir/ label file exists
#     302     if self.args.save or self.args.save_txt:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:256, in BasePredictor.setup_source(self, source, stride)
#     248 """Set up source and inference mode.
#     249
#     250 Args:
#    (...)    253     stride (int, optional): Model stride for image size checking.
#     254 """
#     255 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 256 self.dataset = load_inference_source(
#     257     source=source,
#     258     batch=self.args.batch,
#     259     vid_stride=self.args.vid_stride,
#     260     buffer=self.args.stream_buffer,
#     261     channels=getattr(self.model, "ch", 3),
#     262 )
#     263 self.source_type = self.dataset.source_type
#     264 if (
#     265     self.source_type.stream
#     266     or self.source_type.screenshot
#     267     or len(self.dataset) > 1000  # many images
#     268     or any(getattr(self.dataset, "video_flag", [False]))
#     269 ):  # long sequence
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\data\build.py:432, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     430     dataset = LoadPilAndNumpy(source, channels=channels)
#     431 else:
# --> 432     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     434 # Attach source types to the dataset
#     435 setattr(dataset, "source_type", source_type)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\data\loaders.py:394, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     392     self.cap = None
#     393 if self.nf == 0:
# --> 394     raise FileNotFoundError(f"No images or videos found in {p}. {FORMATS_HELP_MSG}")
#
# FileNotFoundError: No images or videos found in ../results/enhanced_images\detection_outputs. Supported formats are:
# images: {'heic', 'webp', 'tif', 'jpg', 'tiff', 'dng', 'bmp', 'png', 'mpo', 'jpeg', 'pfm'}
# videos: {'ts', 'm4v', 'asf', 'avi', 'mov', 'gif', 'mkv', 'mp4', 'mpg', 'webm', 'wmv', 'mpeg'}

# %%
import os

ENHANCED_PREDICT_DIR = "runs/detect/results/detection_outputs/enhanced/enhanced_images"

print("Exists:", os.path.exists(ENHANCED_PREDICT_DIR))
print("Files:", os.listdir(ENHANCED_PREDICT_DIR)[:5])
# Out:
# Exists: True
# Files: ['1.jpg', '111.jpg', '146.jpg', '179.jpg', '23.jpg']

# %%
import os
import cv2
import matplotlib.pyplot as plt

BASELINE_DIR = "runs/results/detection_outputs/baseline/raw_lowlight"
ENHANCED_DIR = "runs/detect/results/detection_outputs/enhanced/enhanced_images"

print("Baseline exists:", os.path.exists(BASELINE_DIR))
print("Enhanced exists:", os.path.exists(ENHANCED_DIR))

raw_img_name = os.listdir(BASELINE_DIR)[6]
enh_img_name = os.listdir(ENHANCED_DIR)[6]

raw_img = cv2.imread(os.path.join(BASELINE_DIR, raw_img_name))
enh_img = cv2.imread(os.path.join(ENHANCED_DIR, enh_img_name))

raw_img = cv2.cvtColor(raw_img, cv2.COLOR_BGR2RGB)
enh_img = cv2.cvtColor(enh_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.imshow(raw_img)
plt.title("YOLO on Raw Low-Light Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(enh_img)
plt.title("YOLO on Enhanced Image")
plt.axis("off")

plt.show()
# Out:
# Baseline exists: True
# Enhanced exists: True
